# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from sklearn.cross_validation import train_test_split
from sklearn.utils import shuffle
from sklearn import svm

# %%
all_df = pd.read_csv("data/sensor.csv")

# %%
all_df=all_df.drop(['sensor_00'], axis=1)
all_df=all_df.drop(['timestamp'], axis=1)
all_df=all_df.drop(['sensor_01'], axis=1)
all_df=all_df.drop(['sensor_50'], axis=1)
all_df=all_df.drop(['sensor_51'], axis=1)

# %%
all_df['machine_status']= all_df['machine_status'].map({'NORMAL':0, 'BROKEN': 1, 'RECOVERING': 2}).astype(int) 
all_df = all_df.dropna(how='any')

# %%
X=all_df.drop(['machine_status'], axis=1).values.astype('float64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-7043984605db> in <module>()
# ----> 1 X=all_df.drop(['machine_status'], axis=1).values.astype('float64')
#
# ValueError: could not convert string to float: '12:43:00'

# %%
Y = all_df['machine_status'].values.astype('int64')
X.shape

# %%
X = StandardScaler().fit_transform(X)
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X, Y, test_size=0.33, random_state=None) 
Xtrain[:2]
# Out:
# array([[ 0.26367238,  0.62306201, -0.22347434, -0.30188062, -0.35362601,
#         -0.6531357 ,  0.33139898,  0.24605998],
#        [ 0.26336783,  1.32377364, -0.11878128, -0.33435749, -0.4066494 ,
#         -0.81340993,  2.35687472,  2.68291434]])

# %%
Ytrain[:2]
# Out:
# array([0, 0])

# %%
Y[:2]
# Out:
# array([0, 0])

# %%
C = 5.0
classifiers = {
               'RF5': RandomForestClassifier(n_estimators=5),
               'RF50': RandomForestClassifier(n_estimators=50),                
               'tree':DecisionTreeClassifier(criterion='gini',max_depth=5),
                'SVM':svm.SVC(C=5.0,random_state=0, kernel='rbf' ,probability=True)
              }

plt.figure(figsize=(8,8))
n_classifiers = len(classifiers)

# %%
for index, (name, clf) in enumerate(classifiers.items()):
    clf.fit(Xtrain, Ytrain)
    probs = clf.predict_proba(Xtest)
    fpr, tpr, thresholds = roc_curve(Ytest, probs[:, 1])
    roc_auc = auc(fpr, tpr)
    print ('For model', name, 'accuracy =', clf.score(Xtest,Ytest))
    plt.plot(fpr, tpr, label='%s (area = %0.2f)' % (name, roc_auc))
    
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# For model RF50 accuracy = 0.9769764685965804
# For model RF5 accuracy = 0.9756221432199086
# /home/bruce/anaconda3/lib/python3.5/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# For model SVM accuracy = 0.9762993059082444
# For model tree accuracy = 0.9766378872524124
